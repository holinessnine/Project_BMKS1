# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/BKMS1_Project/data'
# Out:
# /content/drive/.shortcut-targets-by-id/1zF2UtsyfygNbdh0VyWpkuEQWy-qdT_rB/BKMS1_Project/data

# %%
import pandas as pd
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
review_db = pd.read_csv('Consolidated Database.csv', index_col=0)
review_db.head()
# Out:
#                                                  product_name condensed_name  \
# product_id
# 1           삼성전자 2019 갤럭시북 플렉스 15.6, 로얄 블루, 코어i5 10세대, 256...       갤럭시북 플렉스
# 1           삼성전자 2019 갤럭시북 플렉스 15.6, 로얄 블루, 코어i5 10세대, 256...       갤럭시북 플렉스
# 1           삼성전자 2020 갤럭시북 플렉스 15.6 + 스마트 S펜, 로얄 블루, 코어i5 ...       갤럭시북 플렉스
# 1           삼성전자 2020 갤럭시북 플렉스 15.6 + 스마트 S펜, 로얄 블루, 코어i5 ...       갤럭시북 플렉스
# 1           삼성전자 2020 갤럭시북 플렉스 15.6 + 스마트 S펜, 로얄 블루, 코어i5 ...       갤럭시북 플렉스
#
#                                                        review Unnamed: 4
# product_id
# 1           삼성 화이트박스에 노트북이 멋지게 들어있더군요^^컬러도 정말 마음에 듭니다. 촌스럽...        NaN
# 1           처음에는 받았을 때 너무 좋았는데 쓰면서도 계속 좋았는데 배터리 남은 시간이 90퍼...        NaN
# 1           플렉스 생각보다 가볍고,디스플레이 크고 디자인 상당히 예쁨 3일정도밖에 안되었지만^...        NaN
# 1           며칠동안 컴고르느라 유튜브 리뷰도 보고 오프라인 매장도 다니고 고생 많이 했는데 역...        NaN
# 1           상품 설치후 재포장 상태 깔끔하게 배송되었으며 상품 코발트 블루 고급지게 보이고 사...        NaN

# %%
#review_db = review_db[review_db['review'] != '등록된 리뷰내용이 없습니다']
#review_db[review_db['review']=='등록된 리뷰내용이 없습니다'].shape
# Out:
# (0, 4)

# %%
review_db1 = review_db[review_db['condensed_name']=='맥북 프로']
review_db2 = review_db[review_db['condensed_name']=='울트라 PC']

# %%
review_db2.head()
# Out:
#            product_name condensed_name  \
# product_id
# 5                   NaN         울트라 PC
# 5                   NaN         울트라 PC
# 5                   NaN         울트라 PC
# 5                   NaN         울트라 PC
# 5                   NaN         울트라 PC
#
#                                                        review Unnamed: 4
# product_id
# 5           최고예요\n진짜 좋은데요~? 지인분 컴퓨터 대신구매해줬는데 진짜 좋습니다. 1. o...        NaN
# 5           가성비 좋은 노트북 입니다.\n집에 데스크탑이 있긴한데 여행가거나 친척집에 가면 아...        NaN
# 5           역시 가성비 최고다. 여기에 엘지가 제공하는 든든한 A/S가 있다. 윈도우 설치 후...        NaN
# 5           노트북 하나 구매해야지 생각만 하고 있다가 쇼핑 라이브할때 우연히 보고 주문햇는데 ...        NaN
# 5           오래 사용한 아버지 pc를 교체하기위해 lg와 삼성 중 고민하다 pc는 역시 lg라...        NaN

# %%
#review_db.to_csv('Consolidated Database.csv')
#reviews = pd.read_csv('Consolidated Database.csv', index_col=0)
#reviews.head()

# %%
# 색상 언급된 리뷰만 추리는 함수
def color_extract(review):
  color_words = '실버 흰색 화이트 검정 블랙 그레이 스페이스 핑크 레드 골드 색감 색상 컬러 칼라 컬러와 은은한 푸른빛 미드나이트'
  color_words = set(color_words.split(' '))
  result = []
  for idx, row in review.iterrows():
    row = row['review']
    sent_lst = sent_tokenize(row)
    for sent in sent_lst:
      words = sent.split(' ')
      for word in words:  
        if word in color_words:
          result.append(sent)
  return result[:5]

print(color_extract(review_db1))
print(color_extract(review_db2))
# Out:
# ['이렇게 적고 나니 진짜 앱등이가 맞네요...원래 삼성 휴대폰만 고집하다가 노트 7 폭발 이슈 이후로 아이폰 7부터 쭉 이용하고 있는데요,아이패드도 사실은 편집용 으로 구매 했는데 넷플릭스용으로 전락 했었어요 ㅠㅠ근데 요번에 해외로 장기체류 하게 되면서 이번 만큼은 정말 유튜브에 영상을 찍어서 올리겠다는 마음가짐으로..당근마켓으로 구매를 해보려다가 시간도 너무 촉박 했었고, 기왕 사는김에 좋은 걸로 사서 오래 쓰자.. 라는 생각으로맥북 프로 13 M2 실버 256GB, 16GB를 구매하게 되었습니다.며칠 전에 봤을 때만 해도 카드 할인이 많이 들어가서 160 만원 대에 구매할 수 있었던 것 같은데, 제가 구매하려고 하니 카드 혜택들이 다 쏙 들어 갔더라구여 ㅠㅠㅠ그래서 170만원 초반대에 구매하게 되었습니다.일단 저로 말씀드리자면, 맥북을 단 한번도 사용해 본 적이 없는.. 맥북 문외한 입니다.그래도 나름 전자기기는 한번 다루기 시작하면 금방금방 배우는 편이라서... 유튜브 찾아보면서 공부하면서 사용하려고 구매하게 되었어요.', '가성비 좋은 아수스 노트북 사용하다가 배터리가 들쑥날쑥 하길래 불안해서 바꾸려고 알아보다가 맥북을 사게 됐어요.회사에서 m1 맥북 사용하긴했지만 집에서 쓰는거랑은 또 다르니까요.배송 빨랐고 박스포장 이중으로 잘 되어있어서 안전하게 왔어요.색상은 스페이스 그레이가 묵직한 느낌이라 맘에 들어요.세세한 설정부터 계정설정까지 다하고 곧장 개발프로그램 이것저것 깔아봤는데 스무스하니 좋네요ㅎㅎ사용한지는 이제 3달 다 되어가네요.m2랑 m1을 램, 메모리 용량 똑같은 맥북 둘다 써봤는데 아주 미세한 차이일수 있지만 m2가 조금 더 매끄럽고 성능이 좋아요.버벅거림이 싫어서 용량을 더 높은걸로 살지 말지 고민했었는데, 이것저것 따져봤을때 굳이?', '직업적으로 프로 16 이상 그리고 M1 프로 급으로 까지 필요하진 않았기에 적당한 것이 맥북프로 13인치 M2 였고, 어쩌다보니 스페이스그레이를 샀는데, 실버가 밝고 이쁘긴하지만, 그래도 뭔가 쓰다
# ...

# %%
# 크기 언급된 리뷰만 추리는 함수
def size_extract(review):
  size_words = '사이즈 사이즈는 커요 크기 작아 작지만 크지만 크기가 크기는'
  size_words = set(size_words.split(' '))
  result = []
  for idx, row in review.iterrows():
    row = row['review']
    sent_lst = sent_tokenize(row)
    for sent in sent_lst:
      words = sent.split(' ')
      for word in words:  
        if word in size_words:
          result.append(sent)
  return result[:5]

print(size_extract(review_db1))
print(size_extract(review_db2))
# Out:
# ['충전기 자체가 너무 크기 때문에 완충해서 나가면 오랜시간 사용할 수 있어서 노트북만 들고 나가면 될 것 같아요!', '13인치 맥북 프로랑 사이즈는 큰\n13인치 맥북 프로랑 사이즈는 큰 차이가 없네요~~', '13인치 맥북 프로랑 사이즈는 큰\n13인치 맥북 프로랑 사이즈는 큰 차이가 없네요~~']
# ['LG 제품 치고는 그리 비싸지 않은 가격에 가성비 좋고 화면 크기 적당하고 흰색 아주 깔끔하구요 선물용인데 받는 사람도 만족해 합니다\nLG 제품 치고는 그리 비싸지 않은 가격에 가성비 좋고 화면 크기 적당하고 흰색 아주 깔끔하구요 선물용인데 받는 사람도 만족해 합니다', 'LG 제품 치고는 그리 비싸지 않은 가격에 가성비 좋고 화면 크기 적당하고 흰색 아주 깔끔하구요 선물용인데 받는 사람도 만족해 합니다\nLG 제품 치고는 그리 비싸지 않은 가격에 가성비 좋고 화면 크기 적당하고 흰색 아주 깔끔하구요 선물용인데 받는 사람도 만족해 합니다']

# %%
# 가격 언급된 리뷰만 추리는 함수
def price_extract(review):
  price_words = '가격 가격대 가격은 가격이 비싸 비싼 싼 비싸지만 비싸요 비싸게 싸요 싸지만 싸게 가성비 할인 할인율 저렴한 저렴하다 저렴하게'
  price_words = set(price_words.split(' '))
  result = []
  for idx, row in review.iterrows():
    row = row['review']
    sent_lst = sent_tokenize(row)
    for sent in sent_lst:
      words = sent.split(' ')
      for word in words:  
        if word in price_words:
          result.append(sent)
  return result[:5]

print(price_extract(review_db1))
print(price_extract(review_db2))
# Out:
# ['가성비 좋은 아수스 노트북 사용하다가 배터리가 들쑥날쑥 하길래 불안해서 바꾸려고 알아보다가 맥북을 사게 됐어요.회사에서 m1 맥북 사용하긴했지만 집에서 쓰는거랑은 또 다르니까요.배송 빨랐고 박스포장 이중으로 잘 되어있어서 안전하게 왔어요.색상은 스페이스 그레이가 묵직한 느낌이라 맘에 들어요.세세한 설정부터 계정설정까지 다하고 곧장 개발프로그램 이것저것 깔아봤는데 스무스하니 좋네요ㅎㅎ사용한지는 이제 3달 다 되어가네요.m2랑 m1을 램, 메모리 용량 똑같은 맥북 둘다 써봤는데 아주 미세한 차이일수 있지만 m2가 조금 더 매끄럽고 성능이 좋아요.버벅거림이 싫어서 용량을 더 높은걸로 살지 말지 고민했었는데, 이것저것 따져봤을때 굳이?', '20여 년 동안 외길만 걸어온 윈도우 콘크리트충입니다.구매에 앞서 가장 큰 망설임은 가격이 아닌, 오직 macOS에 대한 두려움이었다고 생각됩니다.하지만 최근 갤럭시에서 아이폰으로 갈아타며 애플의 위대함을 몸소 깨닫고 용기를 내어 구매를 하였습니다.역시 쿠팡 로켓 배송 답게 다음 날 도착하였고요.두려움 반 설렘 반으로 배송받은 맥북을 미개봉 상태 그대로 집 근처 프리스비 매장으로 가지고 갔습니다.애초에 반품할 마음이 1도 없었기에 거금을 들여 내 외부 전체 필름 시공을 하였습니다.그리고 조심히 집으로 모시고 와서 이렇게 리뷰를 작성하게 되었습니다.제가 구매한 제품 스팩은 램24g 용량512g 실버입니다.맥북프로를 잠시나마 구동해 보니 반응속도와 사용감이 매우 뛰어나 업무 효율을 극대화할 수 있을 것으로 기대합니다.그리고 무엇보다 애플 로고와 외관 디자인이 너무 마음에 듭니다.폼 팩터가 전작이랑 동일하지만 전혀 뒤처지지 않고요.쿠팡 덕분에 카드 할인까지 받아서 오프 대비 저렴하게 구입 한 점도 너무 좋습니다!고민은 배송만 늦출 뿐!', '20여 년 동안 외길만 걸어온 윈도우 콘크리트충입니다.구매에 앞서 가장 큰 망설임은 가격이 아닌, 오직 macOS에 대한 두려움이었다고 생각됩니다.하지만 최근 갤럭시에서 아이폰으로 갈아타며 
# ...

# %% [markdown]
# ## 아래는 무시

# %%
import numpy as np
import itertools

from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
okt = Okt()

tokenized_review = okt.pos(rv1)
tokenized_nouns = ' '.join([word[0] for word in tokenized_review if word[1] == 'Noun'])

print(tokenized_review[:10])
print(tokenized_nouns)
# Out:
# [('당근', 'Noun'), ('에서', 'Josa'), ('미개', 'Noun'), ('봉', 'Noun'), ('구', 'Noun'), ('하다가', 'Verb'), ('실버', 'Noun'), ('색상', 'Noun'), ('은', 'Josa'), ('없어서', 'Adjective')]
# 당근 미개 봉 구 실버 색상 쿠팡 구매 와우 회원 쿠폰 카드 할인 쿠페 결제 시 쿠페 캐시 정도 구매 인터넷 서핑 블로그 등 타이핑 활동 메신저 이용 일 관리 등 개인 노트북 구매 거여 성능 비 저 아주 과분 친구 첫 맥북 버벅거리 부분 일단 아이폰 아이패드 동성 두 가지 키 프로그램 게 발열 못 팬리스 소음 정말 맥 뭐 맥북 그냥 윈도우 노트북 사라 의견 존중 정말 이 가격 이 정도 노트북 윈도우 그램 만큼 어쨋 깡통 성능 저하 이슈 저 라이트 유저 노트북 아이패드 에어팟 프로 더 더욱 추천

# %%
rv1 = coupang.iloc[0, -1]
rv2 = coupang.iloc[1, -1]

# %%
n_gram_range = (2,3)

count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

print(len(candidates))
print(candidates)
# Out:
# 143
# ['가격 정도' '가격 정도 노트북' '가지 프로그램' '가지 프로그램 발열' '개인 노트북' '개인 노트북 구매' '거여 성능'
#  '거여 성능 아주' '결제 쿠페' '결제 쿠페 캐시' '과분 친구' '과분 친구 맥북' '관리 개인' '관리 개인 노트북'
#  '구매 거여' '구매 거여 성능' '구매 와우' '구매 와우 회원' '구매 인터넷' '구매 인터넷 서핑' '그냥 윈도우'
#  '그냥 윈도우 노트북' '그램 만큼' '그램 만큼 어쨋' '깡통 성능' '깡통 성능 저하' '노트북 구매' '노트북 구매 거여'
#  '노트북 사라' '노트북 사라 의견' '노트북 아이패드' '노트북 아이패드 에어팟' '노트북 윈도우' '노트북 윈도우 그램'
#  '당근 미개' '당근 미개 실버' '더욱 추천' '동성 가지' '동성 가지 프로그램' '라이트 유저' '라이트 유저 노트북'
#  '만큼 어쨋' '만큼 어쨋 깡통' '맥북 그냥' '맥북 그냥 윈도우' '맥북 버벅거리' '맥북 버벅거리 부분' '메신저 이용'
#  '메신저 이용 관리' '미개 실버' '미개 실버 색상' '발열 팬리스' '발열 팬리스 소음' '버벅거리 부분'
#  '버벅거리 부분 일단' '부분 일단' '부분 일단 아이폰' '블로그 타이핑' '블로그 타이핑 활동' '사라 의견'
#  '사라 의견 존중' '색상 쿠팡' '색상 쿠팡 구매' '서핑 블로그' '서핑 블로그 타이핑' '성능 아주' '성능 아주 과분'
#  '성능 저하' '성능 저하 이슈' '소음 정말' '소음 정말 맥북' '실버 색상' '실버 색상 쿠팡' '아이패드 동성'
#  '아이패드 동성 가지' '아이패드 에어팟' '아이패드 에어팟 프로' '아이폰 아이패드' '아이폰 아이패드 동성' '아주 과분'
#  '아주 과분 친구' '어쨋 깡통' '어쨋 깡통 성능' '에어팟 프로' '에어팟 프로 더욱' '와우 회원' '와우 회원 쿠폰'
# ...

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
rv_embedding = model.encode([rv1])
candidate_embeddings = model.encode(candidates)
# Out:
# Downloading:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
top_n = 10
distances = cosine_similarity(rv_embedding, candidate_embeddings)
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
print(keywords)
# Out:
# ['아이패드 동성', '라이트 유저 노트북', '노트북 아이패드', '아이패드 동성 가지', '유저 노트북 아이패드', '구매 인터넷 서핑', '관리 개인 노트북', '노트북 아이패드 에어팟', '개인 노트북', '개인 노트북 구매']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from konlpy.tag import Okt

# %%
okt = Okt()

stop_words = ', 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 은 는'
stop_words = set(stop_words.split(' '))
word_tokens = okt.morphs(rv1)

result = [word for word in word_tokens if not word in stop_words]
print(result)
# Out:
# ['당근', '미개', '봉', '하다가', '실버', '색상', '없어서', '쿠팡', '구매', '했습니다', '와우', '회원', '쿠폰', '쓰고', '카드', '할인', '없어서', '쿠페', '결제', '시', '1만원', '쿠페', '캐시', '백', '해서', '139', '구매', '했네요', '인터넷', '서핑', '블로그', '간단한', '타이핑', '활동', '메신저', '이용', '관리', '정말', '정말', '개인', '노트북', '구매', '거여', '서', '본', '성능', '비', '아주', '과분', '친구', '이고', '!', '첫', '맥북', '이라', '아직', '어색하기도', '버벅거리', '부분', '도', '있지만', '너무', '이쁘고', '아이폰', '아이패드', '와의', '연', '동성', '만으로도', '만족합니다', '키', '감도', '좋고', '무거운', '프로그램', '돌리는', '게', '아니라서', '그런지', '발열', '도', '아직', '못', '느껴', '봤고', '팬리스', '여서', '소음', '도', '정말', '없습니다', '맥', '도', '모르면서', '뭐', '하러', '맥북', '사냐', '그냥', '윈도우', '노트북', '사라', '의견', '도', '존중', '정말', '가격', '노트북', '윈도우', '에도', '없더라구요', 'ㅠ', '(', '그램', '..', '가볍고', '좋은', '비싸', ',,,,', 'ㅎㅎ', ')', '어쨋', '든', '깡통', '성능', '저하', '이슈', '도', '있지만', '라이트', '유저', '에겐', '충분히', '좋은', '노트북', '!', '아이패드', '+', '에어팟', '프로', '있으시면', '더욱', '추천', '드립니다', '~!']

# %% [markdown]
# ### 색상

# %%
color_words = '실버 흰색 '

# %% [markdown]
# ### 무게

# %% [markdown]
# ### 디자인

# %% [markdown]
# ### 가격

# %% [markdown]
# ### 성능
